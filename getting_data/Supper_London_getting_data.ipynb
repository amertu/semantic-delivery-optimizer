# %%
import pdb

import os

import numpy as np
import pandas as pd

import json
import requests

import re

import matplotlib.pyplot as plt
import seaborn as sns

# %%
from common_definitions import columns_restaurants, columns_menu

# %%
# define folders
data_folder = './Data'
folder_rest_details = './Supper_London_Details'

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:72.0) Gecko/20100101 Firefox/72.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Origin': 'https://supper.london',
    'Connection': 'keep-alive',
    'Referer': 'https://supper.london/',
}

params = (
    ('postcode', 'SW1H 0NF'),
)

# %%
# get data from the web
get_response = False

if get_response:
    response = requests.get('https://webapi.supper.london/api/restaurants', headers=headers, params=params)

# NB. Original query string below. It seems impossible to parse and
# reproduce query strings 100% accurately so the one below is given
# in case the reproduced version is not "correct".
# response = requests.get('https://webapi.supper.london/api/restaurants?postcode=SW1H%200NF', headers=headers)

# %%
# file for saving the dump
fn_victoria_street = 'Supper_London_response_victoria_street.json'

# %%
# this is the zip code matching the address used
zip_code_victoria = 'SW1H 0NF'

# %%
# basis URL for getting details about a restaurant
base_URL_rest_detail = 'https://webapi.supper.london/api/restaurants/london'

# %%
save_response = False

if save_response:
    # save response as json file
    with open(fn_victoria_street, 'w') as jf:
        json.dump(json.loads(response.content), jf)
        jf.close()

# %%
# load the previously dumped file
with open(fn_victoria_street, 'r') as jf:
    data_vs = json.load(jf)

# %%
key_cuisines = 'Cuisines'
key_rest = 'Restaurants'

# %%
# list of cuisines
data_vs[key_cuisines]
# Out:
# [{'CuisineId': 22, 'CuisineName': 'French'},
#  {'CuisineId': 24, 'CuisineName': 'British'},
#  {'CuisineId': 31, 'CuisineName': 'Wine'},
#  {'CuisineId': 33, 'CuisineName': 'Sweet treats'},
#  {'CuisineId': 46, 'CuisineName': 'Vegan'},
#  {'CuisineId': 1040, 'CuisineName': 'Drinks'},
#  {'CuisineId': 1043, 'CuisineName': 'Vegetarian'},
#  {'CuisineId': 30, 'CuisineName': 'Peruvian'},
#  {'CuisineId': 35, 'CuisineName': 'Seafood'},
#  {'CuisineId': 34, 'CuisineName': 'Pizza'},
#  {'CuisineId': 20, 'CuisineName': 'Japanese'},
#  {'CuisineId': 25, 'CuisineName': 'Italian'},
#  {'CuisineId': 23, 'CuisineName': 'Indian'},
#  {'CuisineId': 40, 'CuisineName': 'Beers'},
#  {'CuisineId': 32, 'CuisineName': 'Grill'},
#  {'CuisineId': 28, 'CuisineName': 'Middle Eastern'},
#  {'CuisineId': 1042, 'CuisineName': 'Greek'},
#  {'CuisineId': 50, 'CuisineName': 'Taiwanese'},
#  {'CuisineId': 1039, 'CuisineName': 'Tea'},
#  {'CuisineId': 36, 'CuisineName': 'American'},
#  {'CuisineId': 26, 'CuisineName': 'Chinese'}]

# %%
# list of restaurants
list_restaurants = data_vs[key_rest]

# %%
# Out:
# {'Cuisines': [{'CuisineId': 22, 'CuisineName': 'French'},
#   {'CuisineId': 24, 'CuisineName': 'British'},
#   {'CuisineId': 31, 'CuisineName': 'Wine'},
#   {'CuisineId': 33, 'CuisineName': 'Sweet treats'},
#   {'CuisineId': 46, 'CuisineName': 'Vegan'},
#   {'CuisineId': 1040, 'CuisineName': 'Drinks'},
#   {'CuisineId': 1043, 'CuisineName': 'Vegetarian'},
#   {'CuisineId': 30, 'CuisineName': 'Peruvian'},
#   {'CuisineId': 35, 'CuisineName': 'Seafood'},
#   {'CuisineId': 34, 'CuisineName': 'Pizza'},
#   {'CuisineId': 20, 'CuisineName': 'Japanese'},
#   {'CuisineId': 25, 'CuisineName': 'Italian'},
#   {'CuisineId': 23, 'CuisineName': 'Indian'},
#   {'CuisineId': 40, 'CuisineName': 'Beers'},
#   {'CuisineId': 32, 'CuisineName': 'Grill'},
#   {'CuisineId': 28, 'CuisineName': 'Middle Eastern'},
#   {'CuisineId': 1042, 'CuisineName': 'Greek'},
#   {'CuisineId': 50, 'CuisineName': 'Taiwanese'},
#   {'CuisineId': 1039, 'CuisineName': 'Tea'},
#   {'CuisineId': 36, 'CuisineName': 'American'},
#   {'CuisineId': 26, 'CuisineName': 'Chinese'}],
#  'Restaurants': [{'Description': 'Mayfair',
#    'Notes': '<h5 class="title">An eclectic, imaginative menu draws on Chef Jean-Georges Vongerichten\'s love of the city</h5> <h5 class="title">and his experiences in the Far East.</h5> <h5 class="title">Beloved British and Connaught classics stand alongside South-east Asian flavours, crafted from</h5> <h5 class="title">fresh-from-the-market ingredients and farm-to-table produce.</h5>',
#    'Recommendations': None,
#    'ToppingsSets': None,
#    'Locations': None,
#    'OpeningHours': None,
#    'IsOpened': True,
#    'MinimumOrder': 20.0,
#    'DeliveryFee': 6.25,
#    'ServiceCharge': 0.0,
#    'RestaurantCommision': 25.0,
#    'IsActive': True,
#    'WaitingTime': 0,
#    'OrderNo': 0,
#    'MobileDescription': None,
#    'UpsellsSetId': 0,
#    'UpsellsSet': None,
#    'AdvancedOrdersDelay': False,
#    'Notifications': None,
#    'DeliveryPriceRanges': None,
#    'ChangeTime': '2020-01-03T10:43:32+00:00',
#    'ChangedByUser': '0551f96c-c7c1-476d-bd20-c47c5c04cda5',
#    'FoodPreparationTime': None,
#    'LocationId': None,
#    'LocationIsOpened': True,
#    'ConcatName': None,
#    'LocationDeliveryRange': None,
#    'LocationFoodPreparationTimeWorkload': None,
#    'LocationPhoneNumber': None,
#    'RestaurantId': 'e7ed2465-17df-4421-8301-ed13754a05d4',
#    'Cuisines': [{'CuisineId': 22, 'CuisineName': 'French'},
#     {'CuisineId': 24, 'CuisineName': 'British'},
#     {'CuisineId': 31, 'CuisineName': 'Wine'},
#     {'CuisineId': 33, 'CuisineName': 'Sweet treats'}],
#    'RestaurantCode': 'jeangeorgesattheconnaught',
#    'RestaurantName': 'Jean-Georges at The Connaught',
#    'LogoImageUrl': 'jeangeorgesattheconnaught/jeangeorgesattheconnaught-logo.jpg',
#    'MainImageUrl': 'jeangeorgesattheconnaught/jeangeorgesattheconnaught-main.jpg',
#    'WebsiteUrl': 'https://www.the-connaught.co.uk/restaurants-bars/jean-georges-at-the-connaught/',
#    'OtherImageUrls': [],
#    'MobileImages': None},
#   {'Description': 'Bloomsbury',
#    'Notes': 'Leading the way on health trends and free-from fare, our nourishing organic food is made using the highest quality natural ingredients with a focus on flavour. Delivered from our health food store in Bloomsbury, all of our food is certified organic and served in plastic-free packaging.',
#    'Recommendations': None,
#    'ToppingsSets': None,
#    'Locations': None,
#    'OpeningHours': None,
#    'IsOpened': True,
#    'MinimumOrder': 15.0,
#    'DeliveryFee': 3.25,
#    'ServiceCharge': 0.0,
#    'RestaurantCommision': 20.0,
#    'IsActive': True,
#    'WaitingTime': 0,
#    'OrderNo': 0,
#    'MobileDescription': None,
#    'UpsellsSetId': 0,
#    'UpsellsSet': None,
#    'AdvancedOrdersDelay': True,
#    'Notifications': None,
#    'DeliveryPriceRanges': None,
#    'ChangeTime': '2019-12-12T14:12:43+00:00',
#    'ChangedByUser': '0551f96c-c7c1-476d-bd20-c47c5c04cda5',
#    'FoodPreparationTime': None,
#    'LocationId': None,
#    'LocationIsOpened': True,
#    'ConcatName': None,
#    'LocationDeliveryRange': None,
#    'LocationFoodPreparationTimeWorkload': None,
#    'LocationPhoneNumber': None,
#    'RestaurantId': '0d27d536-7b19-4b6b-905c-8c70e33dcf67',
#    'Cuisines': [{'CuisineId': 24, 'CuisineName': 'British'},
#     {'CuisineId': 33, 'CuisineName': 'Sweet treats'},
#     {'CuisineId': 46, 'CuisineName': 'Vegan'},
#     {'CuisineId': 1040, 'CuisineName': 'Drinks'},
#     {'CuisineId': 1043, 'CuisineName': 'Vegetarian'}],
#    'RestaurantCode': 'planetorganictorringtonplace',
#    'RestaurantName': 'Planet Organic | Torrington Place',
#    'LogoImageUrl': 'planetorganictorringtonplace/planetorganictorringtonplace-logo.jpg',
#    'MainImageUrl': 'planetorganictorringtonplace/planetorganictorringtonplace-main.jpg',
#    'WebsiteUrl': 'https://www.planetorganic.com/stores/torrington-place-london-wc1e/',
#    'OtherImageUrls': [],
#    'MobileImages': None},
#   {'Description': 'Fitzrovia',
#    'Notes': '<div>Crudo Cevicheria serves up the vibrant flavours of Latin American ceviche in the heart of Fitzrovia.</div> <div>&nbsp;</div> <div>Choose from a selection of signature bowls, or build your own, and enjoy with a variety of sides including traditional Latin American snacks, vegetarian and vegan options.</div>',
#    'Recommendations': None,
#    'ToppingsSets': None,
#    'Locations': None,
#    'OpeningHours': None,
#    'IsOpened': True,
#    'MinimumOrder': 10.0,
#    'DeliveryFee': 3.25,
#    'ServiceCharge': 0.0,
#    'RestaurantCommision': 25.0,
#    'IsActive': True,
#    'WaitingTime': 0,
#    'OrderNo': 1,
#    'MobileDescription': None,
#    'UpsellsSetId': 0,
#    'UpsellsSet': None,
#    'AdvancedOrdersDelay': False,
#    'Notifications': None,
#    'DeliveryPriceRanges': None,
#    'ChangeTime': '2019-12-19T17:13:33+00:00',
#    'ChangedByUser': '358e390f-fee5-42f5-8f04-2ad84e02cd72',
#    'FoodPreparationTime': None,
#    'LocationId': None,
#    'LocationIsOpened': True,
#    'ConcatName': None,
#    'LocationDeliveryRange': None,
#    'LocationFoodPreparationTimeWorkload': None,
#    'LocationPhoneNumber': None,
#    'RestaurantId': '2927bcb2-c541-47d3-a3ea-f77bef104838',
#    'Cuisines': [{'CuisineId': 30, 'CuisineName': 'Peruvian'},
#     {'CuisineId': 35, 'CuisineName': 'Seafood'},
#     {'CuisineId': 46, 'CuisineName': 'Vegan'}],
#    'RestaurantCode': 'crudocevicheria',
#    'RestaurantName': 'Crudo Cevicheria',
#    'LogoImageUrl': 'crudocevicheria/crudocevicheria-logo.jpg',
#    'MainImageUrl': 'crudocevicheria/crudocevicheria-main.jpg',
#    'WebsiteUrl': 'https://www.eatcrudo.com/',
#    'OtherImageUrls': [],
#    'MobileImages': None},
#   {'Description': 'SW3',
#    'Notes': 'EAT WELL. Seasonal, organic food that nourishes. Freshly made by our London farmshops and the award-winning Daylesford Organic Farm in the Cotswolds, one of the most pioneering farms in the UK. Delivered in sustainable packaging.',
#    'Recommendations': None,
#    'ToppingsSets': None,
#    'Locations': None,
#    'OpeningHours': None,
#    'IsOpened': True,
#    'MinimumOrder': 20.0,
#    'DeliveryFee': 3.25,
#    'ServiceCharge': 0.0,
#    'RestaurantCommision': 20.0,
#    'IsActive': True,
#    'WaitingTime': 0,
#    'OrderNo': 1,
#    'MobileDescription': None,
#    'UpsellsSetId': 0,
#    'UpsellsSet': None,
#    'AdvancedOrdersDelay': False,
#    'Notifications': None,
#    'DeliveryPriceRanges': None,
#    'ChangeTime': '2020-01-02T09:08:46+00:00',
#    'ChangedByUser': '0551f96c-c7c1-476d-bd20-c47c5c04cda5',
#    'FoodPreparationTime': None,
#    'LocationId': None,
#    'LocationIsOpened': True,
#    'ConcatName': None,
#    'LocationDeliveryRange': None,
#    'LocationFoodPreparationTimeWorkload': None,
#    'LocationPhoneNumber': None,
#    'RestaurantId': '3a9534be-524b-4c2a-9415-d0245ee5b8d4',
#    'Cuisines': [{'CuisineId': 24, 'CuisineName': 'British'},
#     {'CuisineId': 33, 'CuisineName': 'Sweet treats'},
#     {'CuisineId': 34, 'CuisineName': 'Pizza'},
#     {'CuisineId': 46, 'CuisineName': 'Vegan'},
#     {'CuisineId': 1043, 'CuisineName': 'Vegetarian'}],
#    'RestaurantCode': 'daylesfordorganicbromptoncross',
#    'RestaurantName': 'Daylesford Organic | Brompton Cross',
#    'LogoImageUrl': 'daylesfordorganicbromptoncross/daylesfordorganicbromptoncross-logo.jpg',
#    'MainImageUrl': 'daylesfordorganicbromptoncross/daylesfordorganicbromptoncross-main.jpg',
#    'WebsiteUrl': 'https://www.daylesford.com/contact/',
#    'OtherImageUrls': [],
#    'MobileImages': None},
#   {'Description': 'SW1',
#    'Notes': 'EAT WELL. Seasonal, organic food that nourishes. Freshly made by our London farmshops and the award-winning Daylesford Organic Farm in the Cotswolds, one of the most pioneering farms in the UK. Delivered in sustainable packaging.',
#    'Recommendations': None,
#    'ToppingsSets': None,
#    'Locations': None,
#    'OpeningHours': None,
#    'IsOpened': True,
#    'MinimumOrder': 20.0,
#    'DeliveryFee': 3.25,
#    'ServiceCharge': 0.0,
#    'RestaurantCommision': 20.0,
#    'IsActive': True,
#    'WaitingTime': 0,
#    'OrderNo': 1,
#    'MobileDescription': None,
#    'UpsellsSetId': 0,
#    'UpsellsSet': None,
#    'AdvancedOrdersDelay': False,
#    'Notifications': None,
#    'DeliveryPriceRanges': None,
#    'ChangeTime': '2019-11-06T09:42:50+00:00',
#    'ChangedByUser': '358e390f-fee5-42f5-8f04-2ad84e02cd72',
#    'FoodPreparationTime': None,
#    'LocationId': None,
#    'LocationIsOpened': True,
#    'ConcatName': None,
#    'LocationDeliveryRange': None,
#    'LocationFoodPreparationTimeWorkload': None,
#    'LocationPhoneNumber': None,
#    'RestaurantId': '66b8936d-e72b-4ba0-967b-6e5397c28241',
#    'Cuisines': [{'CuisineId': 24, 'CuisineName': 'British'},
#     {'CuisineId': 31, 'CuisineName': 'Wine'},
#     {'CuisineId': 33, 'CuisineName': 'Sweet treats'},
#     {'CuisineId': 46, 'CuisineName': 'Vegan'},
#     {'CuisineId': 1043, 'CuisineName': 'Vegetarian'}],
#    'RestaurantCode': 'daylesfordorganicpimlico',
#    'RestaurantName': 'Daylesford Organic | Pimlico',
#    'LogoImageUrl': 'daylesfordorganicpimlico/daylesfordorganicpimlico-logo.jpg',
#    'MainImageUrl': 'daylesfordorganicpimlico/daylesfordorganicpimlico-main.jpg',
#    'WebsiteUrl': 'https://www.daylesford.com/contact/',
#    'OtherImageUrls': [],
#    'MobileImages': None},
#   {'Description': 'Marylebone',
#    'Notes': '<p>The Red King Crab is a luxurious, unique delight. The Fancy Crab chefs have created a variety of dishes for you to enjoy, including burgers, salads, and many other main courses. Our menu is a treasure for every fresh seafood connoisseur.</p> <p>We serve our luxurious Red King Crab in two ways: simply on ice with dipping sauces and pickles, or baked over charcoal with butter and thyme, again served with delicious dipping sauces.</p>',
#    'Recommendations': None,
#    'ToppingsSets': None,
#    'Locations': None,
#    'OpeningHours': None,
#    'IsOpened': True,
#    'MinimumOrder': 20.0,
#    'DeliveryFee': 5.95,
#    'ServiceCharge': 0.0,
#    'RestaurantCommision': 25.0,
#    'IsActive': True,
#    'WaitingTime': 0,
#    'OrderNo': 1,
#    'MobileDescription': None,
#    'UpsellsSetId': 0,
#    'UpsellsSet': None,
#    'AdvancedOrdersDelay': False,
#    'Notifications': None,
#    'DeliveryPriceRanges': None,
#    'ChangeTime': '2019-12-20T06:52:17+00:00',
#    'ChangedByUser': '0551f96c-c7c1-476d-bd20-c47c5c04cda5',
#    'FoodPreparationTime': None,
#    'LocationId': None,
#    'LocationIsOpened': True,
#    'ConcatName': None,
#    'LocationDeliveryRange': None,
#    'LocationFoodPreparationTimeWorkload': None,
#    'LocationPhoneNumber': None,
#    'RestaurantId': 'c78ab78a-66a2-4e4f-b939-e2c4bbaa9ed6',
#    'Cuisines': [{'CuisineId': 35, 'CuisineName': 'Seafood'}],
#    'RestaurantCode': 'fancycrab',
#    'RestaurantName': 'Fancy Crab',
#    'LogoImageUrl': 'fancycrab/fancycrab-logo.jpg',
#    'MainImageUrl': 'fancycrab/fancycrab-main.jpg',
#    'WebsiteUrl': 'http://fancycrab.co.uk/contact',
#    'OtherImageUrls': [],
#    'MobileImages': None},
#   {'Description': 'Knightsbridge',
#    'Notes': "<div>Multi award winning, critically acclaimed contemporary Japanese restaurant Sumosan, was founded in 1997 and now boasts restaurants in the most sophisticated locations across the globe including London, Moscow, Monaco and Dubai. Sumosan Twiga, launched in November 2016 in West London&rsquo;s smart Knightsbridge neighborhood, is an exciting expansion of the much loved Sumosan brand in partnership with Flavio Briatore.</div> <div>&nbsp;</div> <div>Offering a winning formula of classic Venetian inspired Italian dishes, paired with Sumosan's contemporary Japanese cuisine, Sumosan Twiga makes a unique entry to the London restaurant scene.</div>",
#    'Recommendations': None,
#    'ToppingsSets': None,
#    'Locations': None,
#    'OpeningHours': None,
#    'IsOpened': True,
#    'MinimumOrder': 20.0,
#    'DeliveryFee': 6.25,
#    'ServiceCharge': 0.0,
#    'RestaurantCommision': 25.0,
#    'IsActive': True,
#    'WaitingTime': 0,
#    'OrderNo': 1,
#    'MobileDescription': None,
#    'UpsellsSetId': 0,
#    'UpsellsSet': None,
#    'AdvancedOrdersDelay': False,
#    'Notifications': None,
#    'DeliveryPriceRanges': None,
#    'ChangeTime': '2020-01-10T07:04:14+00:00',
#    'ChangedByUser': '0551f96c-c7c1-476d-bd20-c47c5c04cda5',
#    'FoodPreparationTime': None,
#    'LocationId': None,
#    'LocationIsOpened': False,
#    'ConcatName': None,
#    'LocationDeliveryRange': None,
#    'LocationFoodPreparationTimeWorkload': None,
#    'LocationPhoneNumber': None,
#    'RestaurantId': 'b475f63a-4566-44e5-9cfb-336e09cd8ec4',
#    'Cuisines': [{'CuisineId': 20, 'CuisineName': 'Japanese'},
#     {'CuisineId': 25, 'CuisineName': 'Italian'},
#     {'CuisineId': 1043, 'CuisineName': 'Vegetarian'}],
#    'RestaurantCode': 'sumosantwiga',
#    'RestaurantName': 'Sumosan Twiga',
#    'LogoImageUrl': 'sumosantwiga/sumosantwiga-logo.jpg',
#    'MainImageUrl': 'sumosantwiga/sumosantwiga-main.jpg',
#    'WebsiteUrl': 'http://www.sumosantwigalondon.com/pages/contact/',
#    'OtherImageUrls': [],
#    'MobileImages': None},
#   {'Description': "St. James's",
#    'Notes': "<p>'O ver is the first restaurant in UK to use the unique ingredient of Pure Sea Water. The menu features wood fired pizzas, fresh pasta, homemade breads, Neapolitan street food, fresh seasonal salads and handmade traditional desserts.</p> ",
#    'Recommendations': None,
#    'ToppingsSets': None,
#    'Locations': None,
#    'OpeningHours': None,
#    'IsOpened': True,
#    'MinimumOrder': 20.0,
#    'DeliveryFee': 3.25,
#    'ServiceCharge': 0.0,
#    'RestaurantCommision': 20.0,
#    'IsActive': True,
#    'WaitingTime': 0,
#    'OrderNo': 2,
#    'MobileDescription': None,
#    'UpsellsSetId': 0,
#    'UpsellsSet': None,
#    'AdvancedOrdersDelay': False,
#    'Notifications': None,
#    'DeliveryPriceRanges': None,
#    'ChangeTime': '2019-12-19T17:30:58+00:00',
#    'ChangedByUser': '358e390f-fee5-42f5-8f04-2ad84e02cd72',
#    'FoodPreparationTime': None,
#    'LocationId': None,
#    'LocationIsOpened': True,
#    'ConcatName': None,
#    'LocationDeliveryRange': None,
#    'LocationFoodPreparationTimeWorkload': None,
#    'LocationPhoneNumber': None,
#    'RestaurantId': 'ae6c537d-6176-44f1-8825-65940938ea11',
#    'Cuisines': [{'CuisineId': 25, 'CuisineName': 'Italian'},
#     {'CuisineId': 33, 'CuisineName': 'Sweet treats'},
#     {'CuisineId': 34, 'CuisineName': 'Pizza'},
#     {'CuisineId': 1043, 'CuisineName': 'Vegetarian'}],
#    'RestaurantCode': 'overstjames',
#    'RestaurantName': "'O ver | St. James's",
#    'LogoImageUrl': 'overstjames/overstjames-logo.jpg',
#    'MainImageUrl': 'overstjames/overstjames-main.jpg',
#    'WebsiteUrl': 'https://www.overuk.com/st-james/',
#    'OtherImageUrls': [],
#    'MobileImages': None},
#   {'Description': 'World famous Italian cuisine',
#    'Notes': "Located in the heart of Mayfair, C London brings it's world renowned Venetian flavours to London. Started in 1931, Giuseppe Cipriani had a vision of simple Italian luxury, that has now turned into a world renowned hospitality brand, often replicated, but never equalled. ",
#    'Recommendations': None,
#    'ToppingsSets': None,
#    'Locations': None,
#    'OpeningHours': '',
#    'IsOpened': True,
#    'MinimumOrder': 25.0,
#    'DeliveryFee': 6.25,
#    'ServiceCharge': 0.0,
#    'RestaurantCommision': 20.0,
#    'IsActive': True,
#    'WaitingTime': 0,
#    'OrderNo': 2,
#    'MobileDescription': None,
#    'UpsellsSetId': 0,
#    'UpsellsSet': None,
#    'AdvancedOrdersDelay': False,
#    'Notifications': None,
#    'DeliveryPriceRanges': None,
#    'ChangeTime': '2019-10-28T16:16:54+00:00',
#    'ChangedByUser': '0551f96c-c7c1-476d-bd20-c47c5c04cda5',
#    'FoodPreparationTime': None,
#    'LocationId': None,
#    'LocationIsOpened': True,
#    'ConcatName': None,
#    'LocationDeliveryRange': None,
#    'LocationFoodPreparationTimeWorkload': None,
#    'LocationPhoneNumber': None,
#    'RestaurantId': 'b605732a-46d8-11e7-abe1-0401eddeae01',
#    'Cuisines': [{'CuisineId': 25, 'CuisineName': 'Italian'}],
#    'RestaurantCode': 'clondon',
#    'RestaurantName': 'C London',
#    'LogoImageUrl': 'clondon/clondon-logo.jpg',
#    'MainImageUrl': 'clondon/clondon-main.jpg',
#    'WebsiteUrl': 'http://www.crestaurant.co.uk/',
#    'OtherImageUrls': [],
#    'MobileImages': None},
#   {'Description': 'Albert Adria at Hotel Cafe Royal',
#    'Notes': '<p>Cakes &amp; Bubbles was born out of Albert Adri&agrave;&rsquo;s desire to open a dessert only venue inspired by &ldquo;La Dol&ccedil;a&rdquo;, the much loved area at Tickets in Barcelona reserved for all things sweet. Following the success of Adri&agrave;&rsquo;s 2016 residency &ldquo;50 Days by Albert Adri&agrave;&rdquo; at Hotel Caf&eacute; Royal, the modern grand hotel in the heart of London nestled between Mayfair and Soho was the obvious choice for our executive chef&rsquo;s first opening outside of his native Spain.</p> <p>&nbsp;</p> <p>You can now enjoy the experience at home with exceptional desserts that defy description along with a wide selection of Champagnes and sparkling wines, from grand marques to home-grown bubbles, all delivered to your home</p>',
#    'Recommendations': None,
#    'ToppingsSets': None,
#    'Locations': None,
#    'OpeningHours': None,
#    'IsOpened': True,
#    'MinimumOrder': 20.0,
#    'DeliveryFee': 5.95,
#    'ServiceCharge': 0.0,
#    'RestaurantCommision': 25.0,
#    'IsActive': True,
#    'WaitingTime': 0,
#    'OrderNo': 2,
#    'MobileDescription': None,
#    'UpsellsSetId': 0,
#    'UpsellsSet': None,
#    'AdvancedOrdersDelay': False,
#    'Notifications': None,
#    'DeliveryPriceRanges': None,
#    'ChangeTime': '2019-12-19T17:18:29+00:00',
#    'ChangedByUser': '358e390f-fee5-42f5-8f04-2ad84e02cd72',
#    'FoodPreparationTime': None,
#    'LocationId': None,
#    'LocationIsOpened': True,
#    'ConcatName': None,
#    'LocationDeliveryRange': None,
#    'LocationFoodPreparationTimeWorkload': None,
#    'LocationPhoneNumber': None,
#    'RestaurantId': 'f6a98cf3-ff2f-4422-a514-7b5248039763',
#    'Cuisines': [{'CuisineId': 33, 'CuisineName': 'Sweet treats'},
#     {'CuisineId': 1040, 'CuisineName': 'Drinks'}],
#    'RestaurantCode': 'cakesandbubbles',
#    'RestaurantName': 'Cakes & Bubbles',
#    'LogoImageUrl': 'cakesandbubbles/cakesandbubbles-logo.jpg',
#    'MainImageUrl': 'cakesandbubbles/cakesandbubbles-main.jpg',
#    'WebsiteUrl': 'https://www.cakesandbubbles.co.uk/contact/',
#    'OtherImageUrls': [],
#    'MobileImages': None},
#   {'Description': 'Battersea Power station',
#    'Notes': 'Experience award-winning Indian dining with innovative and creative, modern Indian cuisine from Chef Vivek Singh at Cinnamon Kitchen.',
#    'Recommendations': None,
#    'ToppingsSets': None,
#    'Locations': None,
#    'OpeningHours': None,
#    'IsOpened': True,
#    'MinimumOrder': 25.0,
#    'DeliveryFee': 3.95,
#    'ServiceCharge': 0.0,
#    'RestaurantCommision': 20.0,
#    'IsActive': True,
#    'WaitingTime': 0,
#    'OrderNo': 2,
#    'MobileDescription': None,
#    'UpsellsSetId': 0,
#    'UpsellsSet': None,
#    'AdvancedOrdersDelay': False,
#    'Notifications': None,
#    'DeliveryPriceRanges': None,
#    'ChangeTime': '2019-10-31T07:01:27+00:00',
#    'ChangedByUser': '0551f96c-c7c1-476d-bd20-c47c5c04cda5',
#    'FoodPreparationTime': None,
#    'LocationId': None,
#    'LocationIsOpened': True,
#    'ConcatName': None,
#    'LocationDeliveryRange': None,
#    'LocationFoodPreparationTimeWorkload': None,
#    'LocationPhoneNumber': None,
#    'RestaurantId': '5d65cf0c-7e6b-47f9-bf6d-8345d229a27b',
#    'Cuisines': [{'CuisineId': 23, 'CuisineName': 'Indian'}],
#    'RestaurantCode': 'cinnamonkitchen',
#    'RestaurantName': 'Cinnamon Kitchen',
#    'LogoImageUrl': 'cinnamonkitchen/cinnamonkitchen-logo.jpg',
#    'MainImageUrl': 'cinnamonkitchen/cinnamonkitchen-main.jpg',
#    'WebsiteUrl': 'http://www.cinnamon-kitchen.com/battersea/',
#    'OtherImageUrls': [],
#    'MobileImages': None},
#   {'Description': '20 inch gourmet pizzas. Classics sit alongside creative flavour combinations.',
#    'Notes': '<h5 class="title">All of Homeslice\'s 20" pizzas are made with their  in-house aged dough, topped with house made sauces and quality, seasonal produce, then cooked in a custom-built wood fired oven.</h5> <h5 class="title">Order whole 20" pizzas or go Half & Half and choose two flavours of your choice.</h5>',
#    'Recommendations': None,
#    'ToppingsSets': None,
#    'Locations': None,
#    'OpeningHours': '',
#    'IsOpened': True,
#    'MinimumOrder': 20.0,
#    'DeliveryFee': 3.25,
#    'ServiceCharge': 0.0,
#    'RestaurantCommision': 20.0,
#    'IsActive': True,
#    'WaitingTime': 0,
#    'OrderNo': 2,
#    'MobileDescription': None,
#    'UpsellsSetId': 1002,
#    'UpsellsSet': None,
#    'AdvancedOrdersDelay': False,
#    'Notifications': None,
#    'DeliveryPriceRanges': None,
#    'ChangeTime': '2020-01-09T16:59:58+00:00',
#    'ChangedByUser': '358e390f-fee5-42f5-8f04-2ad84e02cd72',
#    'FoodPreparationTime': None,
#    'LocationId': None,
#    'LocationIsOpened': True,
#    'ConcatName': None,
#    'LocationDeliveryRange': None,
#    'LocationFoodPreparationTimeWorkload': None,
#    'LocationPhoneNumber': None,
#    'RestaurantId': 'b60583f9-46d8-11e7-abe1-0401eddeae01',
#    'Cuisines': [{'CuisineId': 34, 'CuisineName': 'Pizza'},
#     {'CuisineId': 40, 'CuisineName': 'Beers'},
#     {'CuisineId': 46, 'CuisineName': 'Vegan'},
#     {'CuisineId': 1043, 'CuisineName': 'Vegetarian'}],
#    'RestaurantCode': 'homeslicewestend',
#    'RestaurantName': 'Homeslice | Fitzrovia',
#    'LogoImageUrl': 'homeslicewestend/homeslicewestend-logo.jpg',
#    'MainImageUrl': 'homeslicewestend/homeslicewestend-main.jpg',
#    'WebsiteUrl': 'http://www.homeslicepizza.co.uk/',
#    'OtherImageUrls': [],
#    'MobileImages': None},
#   {'Description': 'Belgravia',
#    'Notes': "Michelin Starred Chef Peter Joseph's fusion menu of classic Indian recipes made with fresh organic British ingredients.",
#    'Recommendations': None,
#    'ToppingsSets': None,
#    'Locations': None,
#    'OpeningHours': None,
#    'IsOpened': True,
#    'MinimumOrder': 20.0,
#    'DeliveryFee': 5.95,
#    'ServiceCharge': 0.0,
#    'RestaurantCommision': 25.0,
#    'IsActive': True,
#    'WaitingTime': 0,
#    'OrderNo': 2,
#    'MobileDescription': None,
#    'UpsellsSetId': 0,
#    'UpsellsSet': None,
#    'AdvancedOrdersDelay': False,
#    'Notifications': None,
#    'DeliveryPriceRanges': None,
#    'ChangeTime': '2019-10-28T16:17:25+00:00',
#    'ChangedByUser': '0551f96c-c7c1-476d-bd20-c47c5c04cda5',
#    'FoodPreparationTime': None,
#    'LocationId': None,
#    'LocationIsOpened': True,
#    'ConcatName': None,
#    'LocationDeliveryRange': None,
#    'LocationFoodPreparationTimeWorkload': None,
#    'LocationPhoneNumber': None,
#    'RestaurantId': 'd800a52c-78e7-4c43-8796-f291a93475fc',
#    'Cuisines': [{'CuisineId': 23, 'CuisineName': 'Indian'},
#     {'CuisineId': 32, 'CuisineName': 'Grill'},
#     {'CuisineId': 1043, 'CuisineName': 'Vegetarian'}],
#    'RestaurantCode': 'Kahani',
#    'RestaurantName': 'Kahani',
#    'LogoImageUrl': 'Kahani/Kahani-logo.jpg',
#    'MainImageUrl': 'Kahani/Kahani-main.jpg',
#    'WebsiteUrl': 'http://kahanilondon.com/',
#    'OtherImageUrls': [],
#    'MobileImages': None},
#   {'Description': 'Carnaby St',
#    'Notes': '<p>Located in the heart of Carnaby, PITTABUN serves up freshly grilled, hand-stretched pittas filled with slow-cooked meats &amp; vegetables finished over real charcoal for a smoky flavour, which are then topped up with homemade velvet sauces. The offering is completed with freshly cut, secretly spiced chips and crunchy colourful salads.</p> <p>*Happy Hour everyday 3-6pm ~ Order any two Pittabuns and receive a portion of fresh chips on the house!*</p>',
#    'Recommendations': None,
#    'ToppingsSets': None,
#    'Locations': None,
#    'OpeningHours': None,
#    'IsOpened': True,
#    'MinimumOrder': 20.0,
#    'DeliveryFee': 3.25,
#    'ServiceCharge': 0.0,
#    'RestaurantCommision': 25.0,
#    'IsActive': True,
#    'WaitingTime': 0,
#    'OrderNo': 2,
#    'MobileDescription': None,
#    'UpsellsSetId': 0,
#    'UpsellsSet': None,
#    'AdvancedOrdersDelay': False,
#    'Notifications': None,
#    'DeliveryPriceRanges': None,
#    'ChangeTime': '2019-12-14T17:03:27+00:00',
#    'ChangedByUser': '0551f96c-c7c1-476d-bd20-c47c5c04cda5',
#    'FoodPreparationTime': None,
#    'LocationId': None,
#    'LocationIsOpened': True,
#    'ConcatName': None,
#    'LocationDeliveryRange': None,
#    'LocationFoodPreparationTimeWorkload': None,
#    'LocationPhoneNumber': None,
#    'RestaurantId': 'd9247afc-4375-4c19-993b-2da1e7322732',
#    'Cuisines': [{'CuisineId': 28, 'CuisineName': 'Middle Eastern'},
#     {'CuisineId': 32, 'CuisineName': 'Grill'},
#     {'CuisineId': 46, 'CuisineName': 'Vegan'},
#     {'CuisineId': 1042, 'CuisineName': 'Greek'},
#     {'CuisineId': 1043, 'CuisineName': 'Vegetarian'}],
#    'RestaurantCode': 'pittabun',
#    'RestaurantName': 'PITTABUN',
#    'LogoImageUrl': 'pittabun/pittabun-logo.jpg',
#    'MainImageUrl': 'pittabun/pittabun-main.jpg',
#    'WebsiteUrl': 'http://www.pittabun.com/',
#    'OtherImageUrls': [],
#    'MobileImages': None},
#   {'Description': 'Authentic Lebanese flatbreads',
#    'Notes': '<h5 class="title">The Lebanese Bakery is a neighbourhood bakery from Beirut that has opened its doors in Covent Garden.</h5> <h5 class="title">The Lebanese Bakery specialise in serving a delicious variety of Lebanese flatbreads (Manousheh), bite sized bakes (Mouajjanet) and lots more...</h5>',
#    'Recommendations': None,
#    'ToppingsSets': None,
#    'Locations': None,
#    'OpeningHours': None,
#    'IsOpened': True,
#    'MinimumOrder': 15.0,
#    'DeliveryFee': 3.25,
#    'ServiceCharge': 0.0,
#    'RestaurantCommision': 20.0,
#    'IsActive': True,
#    'WaitingTime': 0,
#    'OrderNo': 2,
#    'MobileDescription': None,
#    'UpsellsSetId': 0,
#    'UpsellsSet': None,
#    'AdvancedOrdersDelay': False,
#    'Notifications': None,
#    'DeliveryPriceRanges': None,
#    'ChangeTime': '2019-12-14T17:03:38+00:00',
#    'ChangedByUser': '0551f96c-c7c1-476d-bd20-c47c5c04cda5',
#    'FoodPreparationTime': None,
#    'LocationId': None,
#    'LocationIsOpened': True,
#    'ConcatName': None,
#    'LocationDeliveryRange': None,
#    'LocationFoodPreparationTimeWorkload': None,
#    'LocationPhoneNumber': None,
#    'RestaurantId': 'fb85f20c-fbc3-4424-8d34-c91884a0a4ea',
#    'Cuisines': [{'CuisineId': 28, 'CuisineName': 'Middle Eastern'},
#     {'CuisineId': 33, 'CuisineName': 'Sweet treats'}],
#    'RestaurantCode': 'thelebanesebakery',
#    'RestaurantName': 'The Lebanese Bakery',
#    'LogoImageUrl': 'thelebanesebakery/thelebanesebakery-logo.jpg',
#    'MainImageUrl': 'thelebanesebakery/thelebanesebakery-main.jpg',
#    'WebsiteUrl': 'http://thelebanesebakery.com/homepage-london/',
#    'OtherImageUrls': [],
#    'MobileImages': None},
#   {'Description': 'Soho',
#    'Notes': ' Known as the first pioneering brand to introduce the authentic taste of Taiwan Tea, Yi Fang serve the best fruit teas in London. The signature Yi Fang Fruit Tea, a favourite amongst fashionistas, combines Taiwanese tea with fresh seasonal fruit slices.',
#    'Recommendations': None,
#    'ToppingsSets': None,
#    'Locations': None,
#    'OpeningHours': None,
#    'IsOpened': True,
#    'MinimumOrder': 15.0,
#    'DeliveryFee': 3.25,
#    'ServiceCharge': 0.0,
#    'RestaurantCommision': 20.0,
#    'IsActive': True,
#    'WaitingTime': 0,
#    'OrderNo': 2,
#    'MobileDescription': None,
#    'UpsellsSetId': 0,
#    'UpsellsSet': None,
#    'AdvancedOrdersDelay': False,
#    'Notifications': None,
#    'DeliveryPriceRanges': None,
#    'ChangeTime': '2019-12-14T17:03:39+00:00',
#    'ChangedByUser': '0551f96c-c7c1-476d-bd20-c47c5c04cda5',
#    'FoodPreparationTime': None,
#    'LocationId': None,
#    'LocationIsOpened': True,
#    'ConcatName': None,
#    'LocationDeliveryRange': None,
#    'LocationFoodPreparationTimeWorkload': None,
#    'LocationPhoneNumber': None,
#    'RestaurantId': 'cf17f25e-5697-4bca-ac11-aa0c5f3fd5ca',
#    'Cuisines': [{'CuisineId': 50, 'CuisineName': 'Taiwanese'},
#     {'CuisineId': 1039, 'CuisineName': 'Tea'}],
#    'RestaurantCode': 'yifangsoho',
#    'RestaurantName': 'Yi Fang | Soho',
#    'LogoImageUrl': 'yifangsoho/yifangsoho-logo.jpg',
#    'MainImageUrl': 'yifangsoho/yifangsoho-main.jpg',
#    'WebsiteUrl': 'https://www.yifangtea.co.uk/',
#    'OtherImageUrls': [],
#    'MobileImages': None},
#   {'Description': 'Borough Market',
#    'Notes': "<p>'O ver is the first restaurant in UK to use the unique ingredient of Pure Sea Water. The menu features wood fired pizzas, fresh pasta, homemade breads, Neapolitan street food, fresh seasonal salads and handmade traditional desserts.</p> ",
#    'Recommendations': None,
#    'ToppingsSets': None,
#    'Locations': None,
#    'OpeningHours': None,
#    'IsOpened': True,
#    'MinimumOrder': 20.0,
#    'DeliveryFee': 3.25,
#    'ServiceCharge': 0.0,
#    'RestaurantCommision': 20.0,
#    'IsActive': True,
#    'WaitingTime': 0,
#    'OrderNo': 3,
#    'MobileDescription': None,
#    'UpsellsSetId': 0,
#    'UpsellsSet': None,
#    'AdvancedOrdersDelay': False,
#    'Notifications': None,
#    'DeliveryPriceRanges': None,
#    'ChangeTime': '2019-12-26T12:02:27+00:00',
#    'ChangedByUser': '0551f96c-c7c1-476d-bd20-c47c5c04cda5',
#    'FoodPreparationTime': None,
#    'LocationId': None,
#    'LocationIsOpened': True,
#    'ConcatName': None,
#    'LocationDeliveryRange': None,
#    'LocationFoodPreparationTimeWorkload': None,
#    'LocationPhoneNumber': None,
#    'RestaurantId': '4dd9adcc-3c5e-40aa-8988-d4819acc8a0a',
#    'Cuisines': [{'CuisineId': 25, 'CuisineName': 'Italian'},
#     {'CuisineId': 31, 'CuisineName': 'Wine'},
#     {'CuisineId': 33, 'CuisineName': 'Sweet treats'},
#     {'CuisineId': 34, 'CuisineName': 'Pizza'}],
#    'RestaurantCode': 'over',
#    'RestaurantName': "'O ver | Borough",
#    'LogoImageUrl': 'over/over-logo.jpg',
#    'MainImageUrl': 'over/over-main.jpg',
#    'WebsiteUrl': 'https://www.overuk.com/borough/',
#    'OtherImageUrls': [],
#    'MobileImages': None},
#   {'Description': '100% vegan, plant-based, all natural\n',
#    'Notes': '<h5 class="title">Delicious, wholesome, plant-based food that fuels and energises without compromising flavour, taste or satisfaction.</h5> <h5 class="title">At by CHLOE., our goal is simple - to redefine what it means to eat well.</h5>',
#    'Recommendations': None,
#    'ToppingsSets': None,
#    'Locations': None,
#    'OpeningHours': None,
#    'IsOpened': True,
#    'MinimumOrder': 15.0,
#    'DeliveryFee': 3.25,
#    'ServiceCharge': 0.0,
#    'RestaurantCommision': 20.0,
#    'IsActive': True,
#    'WaitingTime': 0,
#    'OrderNo': 3,
#    'MobileDescription': None,
#    'UpsellsSetId': 0,
#    'UpsellsSet': None,
#    'AdvancedOrdersDelay': False,
#    'Notifications': None,
#    'DeliveryPriceRanges': None,
#    'ChangeTime': '2019-12-14T17:03:43+00:00',
#    'ChangedByUser': '0551f96c-c7c1-476d-bd20-c47c5c04cda5',
#    'FoodPreparationTime': None,
#    'LocationId': None,
#    'LocationIsOpened': True,
#    'ConcatName': None,
#    'LocationDeliveryRange': None,
#    'LocationFoodPreparationTimeWorkload': None,
#    'LocationPhoneNumber': None,
#    'RestaurantId': 'b815c3b8-5565-4fdc-9250-030b351b7703',
#    'Cuisines': [{'CuisineId': 24, 'CuisineName': 'British'},
#     {'CuisineId': 33, 'CuisineName': 'Sweet treats'},
#     {'CuisineId': 36, 'CuisineName': 'American'},
#     {'CuisineId': 46, 'CuisineName': 'Vegan'},
#     {'CuisineId': 1043, 'CuisineName': 'Vegetarian'}],
#    'RestaurantCode': 'bychloe',
#    'RestaurantName': 'by CHLOE. | Covent Garden',
#    'LogoImageUrl': 'bychloe/bychloe-logo.jpg',
#    'MainImageUrl': 'bychloe/bychloe-main.jpg',
#    'WebsiteUrl': 'https://eatbychloe.com/faq/',
#    'OtherImageUrls': [],
#    'MobileImages': None},
#   {'Description': 'Knightsbridge',
#    'Notes': "Ishbilia has built a reputation for producing only the finest and most authentic Lebanese cuisine available in London, meaning everyone from celebrities to Sheikhs has been through the doors of London's best Middle Eastern restaurant...",
#    'Recommendations': None,
#    'ToppingsSets': None,
#    'Locations': None,
#    'OpeningHours': '',
#    'IsOpened': True,
#    'MinimumOrder': 25.0,
#    'DeliveryFee': 5.95,
#    'ServiceCharge': 0.0,
#    'RestaurantCommision': 25.0,
#    'IsActive': True,
#    'WaitingTime': 0,
#    'OrderNo': 3,
#    'MobileDescription': None,
#    'UpsellsSetId': 0,
#    'UpsellsSet': None,
#    'AdvancedOrdersDelay': False,
#    'Notifications': None,
#    'DeliveryPriceRanges': None,
#    'ChangeTime': '2019-12-07T12:00:25+00:00',
#    'ChangedByUser': '0551f96c-c7c1-476d-bd20-c47c5c04cda5',
#    'FoodPreparationTime': None,
#    'LocationId': None,
#    'LocationIsOpened': True,
#    'ConcatName': None,
#    'LocationDeliveryRange': None,
#    'LocationFoodPreparationTimeWorkload': None,
#    'LocationPhoneNumber': None,
#    'RestaurantId': 'b6057994-46d8-11e7-abe1-0401eddeae01',
#    'Cuisines': [{'CuisineId': 28, 'CuisineName': 'Middle Eastern'}],
#    'RestaurantCode': 'ishbilia',
#    'RestaurantName': 'Ishbilia',
#    'LogoImageUrl': 'ishbilia/ishbilia-logo.jpg',
#    'MainImageUrl': 'ishbilia/ishbilia-main.jpg',
#    'WebsiteUrl': 'http://www.ishbilia.com/contact-us-2/',
#    'OtherImageUrls': [],
#    'MobileImages': None},
#   {'Description': 'Made with the finest craft spirits',
#    'Notes': '<p>Longﬂint were born from the East London brewing scene with the goal of producing the ﬁnest premium ready-to-serve cocktails made with our pick of the best craft gin, rum and vodka. From our Hibiscus Flower, Gin Tonic to our beautiful Sparkling Rhubarb and Vodka Seltzer, our drinks are made by hand using 100% natural ingredients.</p> <p>The perfect serve for your next team event!</p> <p>*Order by 2pm for next day delivery*</p>',
#    'Recommendations': None,
#    'ToppingsSets': None,
#    'Locations': None,
#    'OpeningHours': None,
#    'IsOpened': True,
#    'MinimumOrder': 25.0,
#    'DeliveryFee': 5.95,
#    'ServiceCharge': 0.0,
#    'RestaurantCommision': 0.0,
#    'IsActive': True,
#    'WaitingTime': 0,
#    'OrderNo': 3,
#    'MobileDescription': None,
#    'UpsellsSetId': 0,
#    'UpsellsSet': None,
#    'AdvancedOrdersDelay': True,
#    'Notifications': None,
#    'DeliveryPriceRanges': None,
#    'ChangeTime': '2020-01-02T09:05:32+00:00',
#    'ChangedByUser': '0551f96c-c7c1-476d-bd20-c47c5c04cda5',
#    'FoodPreparationTime': None,
#    'LocationId': None,
#    'LocationIsOpened': True,
#    'ConcatName': None,
#    'LocationDeliveryRange': None,
#    'LocationFoodPreparationTimeWorkload': None,
#    'LocationPhoneNumber': None,
#    'RestaurantId': '10d90f3a-e65a-433c-962b-55f4f18ddcb3',
#    'Cuisines': [{'CuisineId': 1040, 'CuisineName': 'Drinks'}],
#    'RestaurantCode': 'longflintdrinksco',
#    'RestaurantName': 'Longflint Drinks Co',
#    'LogoImageUrl': 'longflintdrinksco/longflintdrinksco-logo.jpg',
#    'MainImageUrl': 'longflintdrinksco/longflintdrinksco-main.jpg',
#    'WebsiteUrl': 'https://longflint.com/',
#    'OtherImageUrls': [],
#    'MobileImages': None},
#   {'Description': 'Belgravia',
#    'Notes': "Ken Lo's neighbourhood gem, serving Cantonese and Mandarin specialities for over 30 years!",
#    'Recommendations': None,
#    'ToppingsSets': None,
#    'Locations': None,
#    'OpeningHours': '',
#    'IsOpened': True,
#    'MinimumOrder': 25.0,
#    'DeliveryFee': 5.95,
#    'ServiceCharge': 7.0,
#    'RestaurantCommision': 0.0,
#    'IsActive': True,
#    'WaitingTime': 0,
#    'OrderNo': 3,
#    'MobileDescription': None,
#    'UpsellsSetId': 0,
#    'UpsellsSet': None,
#    'AdvancedOrdersDelay': False,
#    'Notifications': None,
#    'DeliveryPriceRanges': None,
#    'ChangeTime': '2019-12-26T12:02:26+00:00',
#    'ChangedByUser': '0551f96c-c7c1-476d-bd20-c47c5c04cda5',
#    'FoodPreparationTime': None,
#    'LocationId': None,
#    'LocationIsOpened': True,
#    'ConcatName': None,
#    'LocationDeliveryRange': None,
#    'LocationFoodPreparationTimeWorkload': None,
#    'LocationPhoneNumber': None,
#    'RestaurantId': 'b605787f-46d8-11e7-abe1-0401eddeae01',
#    'Cuisines': [{'CuisineId': 26, 'CuisineName': 'Chinese'}],
#    'RestaurantCode': 'memoriesofchina',
#    'RestaurantName': 'Memories of China',
#    'LogoImageUrl': 'memoriesofchina/memoriesofchina-logo.jpg',
#    'MainImageUrl': 'memoriesofchina/memoriesofchina-main.jpg',
#    'WebsiteUrl': 'http://kenlosmemoriesofchina.com/',
#    'OtherImageUrls': [],
#    'MobileImages': None},
#   {'Description': 'Chelsea\n\n',
#    'Notes': 'Scalini is one of the oldest traditional Italian restaurants in London, beloved by the local community, celebrities and lovers of traditional Italian food everywhere.',
#    'Recommendations': None,
#    'ToppingsSets': None,
#    'Locations': None,
#    'OpeningHours': '',
#    'IsOpened': True,
#    'MinimumOrder': 25.0,
#    'DeliveryFee': 6.25,
#    'ServiceCharge': 7.0,
#    'RestaurantCommision': 0.0,
#    'IsActive': True,
#    'WaitingTime': 0,
#    'OrderNo': 3,
#    'MobileDescription': None,
#    'UpsellsSetId': 0,
#    'UpsellsSet': None,
#    'AdvancedOrdersDelay': False,
#    'Notifications': None,
#    'DeliveryPriceRanges': None,
#    'ChangeTime': '2019-12-26T12:02:29+00:00',
#    'ChangedByUser': '0551f96c-c7c1-476d-bd20-c47c5c04cda5',
#    'FoodPreparationTime': None,
#    'LocationId': None,
#    'LocationIsOpened': False,
#    'ConcatName': None,
#    'LocationDeliveryRange': None,
#    'LocationFoodPreparationTimeWorkload': None,
#    'LocationPhoneNumber': None,
#    'RestaurantId': 'b605782e-46d8-11e7-abe1-0401eddeae01',
#    'Cuisines': [{'CuisineId': 25, 'CuisineName': 'Italian'}],
#    'RestaurantCode': 'scalini',
#    'RestaurantName': 'Scalini',
#    'LogoImageUrl': 'scalini/scalini-logo.jpg',
#    'MainImageUrl': 'scalini/scalini-main.jpg',
#    'WebsiteUrl': 'https://scalinilondon.co.uk/',
#    'OtherImageUrls': [],
#    'MobileImages': None},
#   {'Description': '"Some genius has created skinny prosecco and we are eternally grateful." \u200b The Metro',
#    'Notes': 'Thomson & Scott Prosecco and Champagne has taken the UK by storm. Boasting as little as 0.1g of sugar per litre compared with the traditional 12.5g of sugar found in most Prosecco,  the whole range is 100% organically produced and delicious.',
#    'Recommendations': None,
#    'ToppingsSets': None,
#    'Locations': None,
#    'OpeningHours': ' ',
#    'IsOpened': True,
#    'MinimumOrder': 20.0,
#    'DeliveryFee': 5.95,
#    'ServiceCharge': 0.0,
#    'RestaurantCommision': 20.0,
#    'IsActive': True,
#    'WaitingTime': 0,
#    'OrderNo': 3,
#    'MobileDescription': None,
#    'UpsellsSetId': 0,
#    'UpsellsSet': None,
#    'AdvancedOrdersDelay': False,
#    'Notifications': None,
#    'DeliveryPriceRanges': None,
#    'ChangeTime': '2019-12-26T12:02:31+00:00',
#    'ChangedByUser': '0551f96c-c7c1-476d-bd20-c47c5c04cda5',
#    'FoodPreparationTime': None,
#    'LocationId': None,
#    'LocationIsOpened': True,
#    'ConcatName': None,
#    'LocationDeliveryRange': None,
#    'LocationFoodPreparationTimeWorkload': None,
#    'LocationPhoneNumber': None,
#    'RestaurantId': 'e4038610-2962-4e12-8e8d-b626091ff762',
#    'Cuisines': [{'CuisineId': 31, 'CuisineName': 'Wine'},
#     {'CuisineId': 46, 'CuisineName': 'Vegan'}],
#    'RestaurantCode': 'skinnyprosecco',
#    'RestaurantName': 'Thomson & Scott',
#    'LogoImageUrl': 'skinnyprosecco/skinnyprosecco-logo.jpg',
#    'MainImageUrl': 'skinnyprosecco/skinnyprosecco-main.jpg',
#    'WebsiteUrl': 'https://www.thomsonandscott.com/contact',
#    'OtherImageUrls': [],
#    'MobileImages': None},
#   {'Description': 'Curated wine from Sipp.',
#    'Notes': 'Sipp have a knack for finding the hidden gems of the wine world. These are artisan producers from classic regions that they’ve hand picked for their story and their flavour. They’re committed to bringing you these wines exclusively and at great prices. All you have to do is Sipp.',
#    'Recommendations': None,
#    'ToppingsSets': None,
#    'Locations': None,
#    'OpeningHours': '',
#    'IsOpened': True,
#    'MinimumOrder': 20.0,
#    'DeliveryFee': 5.95,
#    'ServiceCharge': 0.0,
#    'RestaurantCommision': 20.0,
#    'IsActive': True,
#    'WaitingTime': 0,
#    'OrderNo': 3,
#    'MobileDescription': None,
#    'UpsellsSetId': 0,
#    'UpsellsSet': None,
#    'AdvancedOrdersDelay': False,
#    'Notifications': None,
#    'DeliveryPriceRanges': None,
#    'ChangeTime': '2019-12-26T12:02:32+00:00',
#    'ChangedByUser': '0551f96c-c7c1-476d-bd20-c47c5c04cda5',
#    'FoodPreparationTime': None,
#    'LocationId': None,
#    'LocationIsOpened': True,
#    'ConcatName': None,
#    'LocationDeliveryRange': None,
#    'LocationFoodPreparationTimeWorkload': None,
#    'LocationPhoneNumber': None,
#    'RestaurantId': 'b6057b77-46d8-11e7-abe1-0401eddeae01',
#    'Cuisines': [{'CuisineId': 31, 'CuisineName': 'Wine'}],
#    'RestaurantCode': 'wine',
#    'RestaurantName': 'Wine',
#    'LogoImageUrl': 'wine/wine-logo.jpg',
#    'MainImageUrl': 'wine/wine-main.jpg',
#    'WebsiteUrl': None,
#    'OtherImageUrls': [],
#    'MobileImages': None},
#   {'Description': 'Mayfair',
#    'Notes': 'Delfino is a Mount St institution making authentic Pizzas and Italian classics for over 50 years',
#    'Recommendations': None,
#    'ToppingsSets': None,
#    'Locations': None,
#    'OpeningHours': '',
#    'IsOpened': True,
#    'MinimumOrder': 25.0,
#    'DeliveryFee': 5.95,
#    'ServiceCharge': 7.0,
#    'RestaurantCommision': 12.0,
#    'IsActive': True,
#    'WaitingTime': 0,
#    'OrderNo': 4,
#    'MobileDescription': None,
#    'UpsellsSetId': 0,
#    'UpsellsSet': None,
#    'AdvancedOrdersDelay': False,
#    'Notifications': None,
#    'DeliveryPriceRanges': None,
#    'ChangeTime': '2020-01-03T10:47:22+00:00',
#    'ChangedByUser': '0551f96c-c7c1-476d-bd20-c47c5c04cda5',
#    'FoodPreparationTime': None,
#    'LocationId': None,
#    'LocationIsOpened': True,
#    'ConcatName': None,
#    'LocationDeliveryRange': None,
#    'LocationFoodPreparationTimeWorkload': None,
#    'LocationPhoneNumber': None,
#    'RestaurantId': 'b6058132-46d8-11e7-abe1-0401eddeae01',
#    'Cuisines': [{'CuisineId': 25, 'CuisineName': 'Italian'},
#     {'CuisineId': 34, 'CuisineName': 'Pizza'}],
#    'RestaurantCode': 'delfino',
#    'RestaurantName': 'Delfino',
#    'LogoImageUrl': 'delfino/delfino-logo.jpg',
#    'MainImageUrl': 'delfino/delfino-main.jpg',
#    'WebsiteUrl': 'http://www.finos.co.uk/delfinos/contact',
#    'OtherImageUrls': [],
#    'MobileImages': None},
#   {'Description': 'Piccadilly',
#    'Notes': 'Purveyors of traditional and elegant seafood, Caviar House & Prunier specialises in a range of top quality caviar and Norwegian smoked salmon cured in their in-house smokery. ',
#    'Recommendations': None,
#    'ToppingsSets': None,
#    'Locations': None,
#    'OpeningHours': '',
#    'IsOpened': True,
#    'MinimumOrder': 25.0,
#    'DeliveryFee': 6.25,
#    'ServiceCharge': 9.0,
#    'RestaurantCommision': 0.0,
#    'IsActive': True,
#    'WaitingTime': 0,
#    'OrderNo': 5,
#    'MobileDescription': '*TEXT*',
#    'UpsellsSetId': 0,
#    'UpsellsSet': None,
#    'AdvancedOrdersDelay': False,
#    'Notifications': None,
#    'DeliveryPriceRanges': None,
#    'ChangeTime': '2020-01-02T09:05:39+00:00',
#    'ChangedByUser': '0551f96c-c7c1-476d-bd20-c47c5c04cda5',
#    'FoodPreparationTime': None,
#    'LocationId': None,
#    'LocationIsOpened': True,
#    'ConcatName': None,
#    'LocationDeliveryRange': None,
#    'LocationFoodPreparationTimeWorkload': None,
#    'LocationPhoneNumber': None,
#    'RestaurantId': 'b60583a9-46d8-11e7-abe1-0401eddeae01',
#    'Cuisines': [{'CuisineId': 35, 'CuisineName': 'Seafood'}],
#    'RestaurantCode': 'prunier',
#    'RestaurantName': 'Caviar House & Prunier',
#    'LogoImageUrl': 'prunier/prunier-logo.jpg',
#    'MainImageUrl': 'prunier/prunier-main.jpg',
#    'WebsiteUrl': 'https://www.caviarhouse-prunier.co.uk/',
#    'OtherImageUrls': [],
#    'MobileImages': None},
#   {'Description': "St. James's",
#    'Notes': 'Farzi Café is a Modern Spice Bistro serving cutting edge avant-garde Indian cuisine with a twist. The techniques might be new, the ingredients might be global, but the focus is on unapologetic  authenticity that still suits every palate.',
#    'Recommendations': None,
#    'ToppingsSets': None,
#    'Locations': None,
#    'OpeningHours': None,
#    'IsOpened': False,
#    'MinimumOrder': 20.0,
#    'DeliveryFee': 5.95,
#    'ServiceCharge': 0.0,
#    'RestaurantCommision': 20.0,
#    'IsActive': True,
#    'WaitingTime': 0,
#    'OrderNo': 6,
#    'MobileDescription': None,
#    'UpsellsSetId': 0,
#    'UpsellsSet': None,
#    'AdvancedOrdersDelay': False,
#    'Notifications': None,
#    'DeliveryPriceRanges': None,
#    'ChangeTime': '2019-12-19T17:33:59+00:00',
#    'ChangedByUser': '358e390f-fee5-42f5-8f04-2ad84e02cd72',
#    'FoodPreparationTime': None,
#    'LocationId': None,
#    'LocationIsOpened': False,
#    'ConcatName': None,
#    'LocationDeliveryRange': None,
#    'LocationFoodPreparationTimeWorkload': None,
#    'LocationPhoneNumber': None,
#    'RestaurantId': '7ed8d652-8515-4de8-9527-25b7b5067263',
#    'Cuisines': [{'CuisineId': 23, 'CuisineName': 'Indian'},
#     {'CuisineId': 1043, 'CuisineName': 'Vegetarian'}],
#    'RestaurantCode': 'farzicafe',
#    'RestaurantName': 'Farzi Café',
#    'LogoImageUrl': 'farzicafe/farzicafe-logo.jpg',
#    'MainImageUrl': 'farzicafe/farzicafe-main.jpg',
#    'WebsiteUrl': 'https://www.farzilondon.com/',
#    'OtherImageUrls': [],
#    'MobileImages': None}]}

# %%
# Mapping: {ours: theirs}

mapper = {'name' : 'RestaurantName',
          'delivery_charge': 'DeliveryFee',
          'waiting_time': 'WaitingTime',
          'min_order': 'MinimumOrder'}

restaurant_URL_substr = 'RestaurantCode'

# %%
# for each restaurant, get detailed info
# and dump to file if not already on disk
for rest in list_restaurants:
    print('name: ', rest[mapper['name']])
    
    rest_detail_fn = os.path.join(folder_rest_details, rest[restaurant_URL_substr] + '.json')
    
    if os.path.isfile(rest_detail_fn):
        print('file exists')
        with open(rest_detail_fn, 'r') as jf:
            data_current_rest = json.load(jf)
    else:
        rest_URL = '/'.join([base_URL_rest_detail, rest[restaurant_URL_substr], zip_code_victoria])
        response_rest = requests.get(rest_URL)
    
        # dump json for the restaurant
        # rest_detail_fn + '.json'
        with open(rest_detail_fn, 'w') as jf:
            json.dump(json.loads(response_rest.content), jf)
            jf.close()

# %%
# set up lists for collecting the data
names = []
deliv_charge = []
waiting_time = []
cuisines = []
minimum_order = []

restaurant_code = []

# %%
# fill the data frame for the non-detailed stuff on the restaurants
for rest in list_restaurants:
    print('name: ', rest[mapper['name']])
    
    names.append(rest[mapper['name']])
    waiting_time.append(rest[mapper['waiting_time']])
    deliv_charge.append(rest[mapper['delivery_charge']])
    minimum_order.append(rest[mapper['min_order']])
    
    restaurant_code.append(rest['RestaurantCode'])
    
    cuis = []
    for elem in rest['Cuisines']:
        cuis.append(elem['CuisineName'])
        
    print(cuis)
    cuisines.append(cuis)
# Out:
# name:  Jean-Georges at The Connaught
# ['French', 'British', 'Wine', 'Sweet treats']
# name:  Planet Organic | Torrington Place
# ['British', 'Sweet treats', 'Vegan', 'Drinks', 'Vegetarian']
# name:  Crudo Cevicheria
# ['Peruvian', 'Seafood', 'Vegan']
# name:  Daylesford Organic | Brompton Cross
# ['British', 'Sweet treats', 'Pizza', 'Vegan', 'Vegetarian']
# name:  Daylesford Organic | Pimlico
# ['British', 'Wine', 'Sweet treats', 'Vegan', 'Vegetarian']
# name:  Fancy Crab
# ['Seafood']
# name:  Sumosan Twiga
# ['Japanese', 'Italian', 'Vegetarian']
# name:  'O ver | St. James's
# ['Italian', 'Sweet treats', 'Pizza', 'Vegetarian']
# name:  C London
# ['Italian']
# name:  Cakes & Bubbles
# ['Sweet treats', 'Drinks']
# name:  Cinnamon Kitchen
# ['Indian']
# name:  Homeslice | Fitzrovia
# ['Pizza', 'Beers', 'Vegan', 'Vegetarian']
# name:  Kahani
# ['Indian', 'Grill', 'Vegetarian']
# name:  PITTABUN
# ['Middle Eastern', 'Grill', 'Vegan', 'Greek', 'Vegetarian']
# name:  The Lebanese Bakery
# ['Middle Eastern', 'Sweet treats']
# name:  Yi Fang | Soho
# ['Taiwanese', 'Tea']
# name:  'O ver | Borough
# ['Italian', 'Wine', 'Sweet treats', 'Pizza']
# name:  by CHLOE. | Covent Garden
# ['British', 'Sweet treats', 'American', 'Vegan', 'Vegetarian']
# name:  Ishbilia
# ['Middle Eastern']
# name:  Longflint Drinks Co
# ['Drinks']
# name:  Memories of China
# ['Chinese']
# name:  Scalini
# ['Italian']
# name:  Thomson & Scott
# ['Wine', 'Vegan']
# name:  Wine
# ['Wine']
# name:  Delfino
# ['Italian', 'Pizza']
# name:  Caviar House & Prunier
# ['Seafood']
# name:  Farzi Café
# ['Indian', 'Vegetarian']

# %%
# # len(list_restaurants)
# print(len(names))
# print(len(cuisines))
# print(len(waiting_time))
# print(len(deliv_charge))

# %%
# set up the dataframe
restaurants_df = pd.DataFrame(columns=columns_restaurants)

restaurants_df['name'] = names
restaurants_df['cuisine'] = cuisines
restaurants_df['waiting_time'] = waiting_time
restaurants_df['delivery_charge'] = deliv_charge
restaurants_df['data_source'] = ['Supper'] * len(list_restaurants)
restaurants_df['min_order'] = minimum_order

restaurants_df['restaurant_code'] = restaurant_code

# %%
restaurants_df.shape
# Out:
# (27, 27)

# %%
restaurants_df.head(2)
# Out:
#                                 name  \
# 0      Jean-Georges at The Connaught
# 1  Planet Organic | Torrington Place
#
#                                              cuisine description  \
# 0              [French, British, Wine, Sweet treats]         NaN
# 1  [British, Sweet treats, Vegan, Drinks, Vegetar...         NaN
#
#   price_category breakfast lunch sandwiches city post_code street  ...  \
# 0            NaN       NaN   NaN        NaN  NaN       NaN    NaN  ...
# 1            NaN       NaN   NaN        NaN  NaN       NaN    NaN  ...
#
#   min_order payment_cash payment_card waiting_time delivery_time  \
# 0      20.0          NaN          NaN            0           NaN
# 1      15.0          NaN          NaN            0           NaN
#
#   delivery_postcode  rating_value  rating_count data_source  \
# 0               NaN           NaN           NaN      Supper
# 1               NaN           NaN           NaN      Supper
#
#                 restaurant_code
# 0     jeangeorgesattheconnaught
# 1  planetorganictorringtonplace
#
# [2 rows x 27 columns]

# %%
# list_restaurants

# %%
# load restaurant details and process data
rest_details_list = os.listdir('./Supper_London_Details/')
rest_details_list = [x for x in rest_details_list if x.endswith('.json')]

# %%
# from the detail files, collect menu items,
# and some extra info
menu_items = []
extra_info = []

for rest_detail_fn in rest_details_list:
    with open(os.path.join(folder_rest_details, rest_detail_fn), 'r') as jf:
        data_current_rest = json.load(jf)
        
        latitude = data_current_rest['Locations'][0]['Latitude']
        longitude = data_current_rest['Locations'][0]['Longitude']
        address = data_current_rest['Locations'][0]['Address']
        postcode = data_current_rest['Locations'][0]['Postcode']

        try:
            city = address.split(',')[1]
        except:
            city = None
        
        leading_nr = re.findall('^\d+\s[A-z]+\s[A-z]+', address)
        leading_nr_2 = re.findall('^\d+\s[A-z]+', address)
        if leading_nr or leading_nr_2:
            number = address.split(' ')[0].strip()
            address = ' '.join(address.split(' ')[1:]).strip()
        else:
            number = None
        
        
        restaurant_code = data_current_rest['RestaurantCode']
        
        extra_info.append([restaurant_code, address, postcode, latitude, longitude, number, city])
        
        # get menu data
        list_cat = data_current_rest['DefaultMenu']['Categories']
        
#         current_menu = []
        
        for cat in list_cat:
            menu_items_list = cat['MenuItems']
            
            for elem in menu_items_list:
                name = elem['MenuItemName']
                restaurant_name = elem['RestaurantCode']
                description = elem['Description']
                price = elem['Price']

#                 print('name: ', name)
#                 print('price: ', price)
                
#                 current_menu.append([name, restaurant_name, description, price])
                menu_items.append([name, restaurant_name, description, price])
        
#         print(latitude)
#         print(longitude)
#         print(address)
#         print(postcode)

# %%
menu_df = pd.DataFrame(menu_items, columns=['name', 'restaurant_name', 'description', 'price'])

# %%
menu_df.head(2)
# Out:
#                            name            restaurant_name  \
# 0                 Afternoon Tea  jeangeorgesattheconnaught
# 1  Kale & Roasted Pumpkin Salad  jeangeorgesattheconnaught
#
#                                          description  price
# 0  A selection of finger sandwiches, pastries and...   55.0
# 1           Russet Apples, Red Wine Vinegar Dressing   21.0

# %%
extra_df = pd.DataFrame(extra_info, columns=['restaurant_code', 'street', 'post_code', 'latitude', 'longitude', 'number', 'city'])

# %%
extra_df.head()
# Out:
#              restaurant_code                                        street  \
# 0  jeangeorgesattheconnaught  The Connaught, Carlos Place, Mayfair, London
# 1                    clondon                          23- 25 Davies Street
# 2                  fancycrab                        Wigmore St, Marylebone
# 3            cinnamonkitchen                                   Arches Lane
# 4            memoriesofchina                            65-69 Ebury Street
#
#    post_code   latitude  longitude number           city
# 0  W1K 2AL     0.000000   0.000000   None   Carlos Place
# 1     W1K3DE  51.511547  -0.147962   None           None
# 2    W1U 3RD   0.000000   0.000000     92     Marylebone
# 3    SW8 4PP   0.000000   0.000000      4           None
# 4   SW1W 0NZ  51.494919  -0.147433   None           None

# %%
# restaurants_df.merge(extra_df, how='outer', on='restaurant_code').head(3)

# %%
assert restaurants_df.shape[0] == extra_df.shape[0]

# %%
restaurants_df.sort_values('restaurant_code', inplace=True)
extra_df.sort_values('restaurant_code', inplace=True)

# %%
# fill in the extra data
for col in extra_df.columns[1:]:
    restaurants_df[col] = extra_df[col]

# %%
restaurants_df.head(3)
# Out:
#                          name  \
# 12                     Kahani
# 17  by CHLOE. | Covent Garden
# 9             Cakes & Bubbles
#
#                                               cuisine description  \
# 12                        [Indian, Grill, Vegetarian]         NaN
# 17  [British, Sweet treats, American, Vegan, Veget...         NaN
# 9                              [Sweet treats, Drinks]         NaN
#
#    price_category breakfast lunch sandwiches                city post_code  \
# 12            NaN       NaN   NaN        NaN           Belgravia  SW1X 9QB
# 17            NaN       NaN   NaN        NaN   St James's Market   SW1Y4RJ
# 9             NaN       NaN   NaN        NaN                None    W1W6AB
#
#                           street  ... min_order payment_cash payment_card  \
# 12          Sloane St, Belgravia  ...      20.0          NaN          NaN
# 17  Norris St, St James's Market  ...      15.0          NaN          NaN
# 9            3-8 Bolsover Street  ...      20.0          NaN          NaN
#
#    waiting_time  delivery_time  delivery_postcode  rating_value  rating_count  \
# 12            0            NaN                NaN           NaN           NaN
# 17            0            NaN                NaN           NaN           NaN
# 9             0            NaN                NaN           NaN           NaN
#
#    data_source  restaurant_code
# 12      Supper           Kahani
# 17      Supper          bychloe
# 9       Supper  cakesandbubbles
#
# [3 rows x 27 columns]

# %%
restaurant_menu = pd.merge(restaurants_df, menu_df, how='left', left_on=['restaurant_code'], right_on=['restaurant_name'])

# %%
restaurant_menu.head(3)
# Out:
#    name_x                      cuisine description_x price_category breakfast  \
# 0  Kahani  [Indian, Grill, Vegetarian]           NaN            NaN       NaN
# 1  Kahani  [Indian, Grill, Vegetarian]           NaN            NaN       NaN
# 2  Kahani  [Indian, Grill, Vegetarian]           NaN            NaN       NaN
#
#   lunch sandwiches        city post_code                street  ...  \
# 0   NaN        NaN   Belgravia  SW1X 9QB  Sloane St, Belgravia  ...
# 1   NaN        NaN   Belgravia  SW1X 9QB  Sloane St, Belgravia  ...
# 2   NaN        NaN   Belgravia  SW1X 9QB  Sloane St, Belgravia  ...
#
#   delivery_time delivery_postcode rating_value rating_count  data_source  \
# 0           NaN               NaN          NaN          NaN       Supper
# 1           NaN               NaN          NaN          NaN       Supper
# 2           NaN               NaN          NaN          NaN       Supper
#
#    restaurant_code                   name_y  restaurant_name  \
# 0           Kahani  Beetroot, Peach, Apple            Kahani
# 1           Kahani            Black Chicken           Kahani
# 2           Kahani         Spiced Chickpeas           Kahani
#
#                                        description_y price
# 0            With baby leaves, pinenuts and mustard    8.0
# 1          Chetinaad roasted spice and curry leaves   10.0
# 2  With sweetened yoghurt, mint, tamarind chutney...  10.0
#
# [3 rows x 31 columns]

# %%
restaurant_menu.to_json(os.path.join(data_folder, 'supper_london_with_menu.json'))
